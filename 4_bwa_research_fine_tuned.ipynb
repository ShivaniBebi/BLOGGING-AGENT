# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_24728\650554995.py:18: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Self Attention")
# Out:
# ====================================================================================================
# TOPIC: Write a blog on Self Attention
# AS_OF: 2026-07-06 RECENCY_DAYS: 3650
# MODE: closed_book
# BLOG_KIND: explainer
# NEEDS_RESEARCH: False
# QUERIES: []
# EVIDENCE_COUNT: 0
# TASKS: 6
# SAVED_MD_CHARS: 15271
# ====================================================================================================
# {'topic': 'Write a blog on Self Attention',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Understanding Self-Attention: Foundations and Applications', audience='Developers and machine learning engineers with some knowledge of neural networks', tone='Informative and practical', blog_kind='explainer', constraints=['Avoid overly technical jargon', 'Include actionable insights', 'Focus on clarity and intuition'], tasks=[Task(id=1, title='Introduction to Self-Attention', goal='Explain what self-attention is and its significance in neural networks.', bullets=['Define self-attention and distinguish it from traditional attention mechanisms', 'Outline the historical context and motivation for using self-attention', 'Describe key differences between self-attention and convolutional or recurrent operations', 'Explain high-level intuition on how self-attention captures relationships within input sequence elements', 'Highlight common domains and tasks where self-attention is instrumental, like NLP and computer vision'], target_words=250, tags=['introduction'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Core Mechanics of Self-Attention', goal='Detail the mathematical and computational steps involved in self-attention.', bullets=['Explain the concepts of queries, keys, and values in the self-attention context', 'Describe how attention scores are calculated using dot product and scaled by dimensionality', 'Outline the softmax step to normalize attention weights', 'Show how attention weights are applied to values to produce attended representations', 'Discuss multi-head attention to capture diverse representation subspaces', 'Include a minimal code sketch for self-attention computations (e.g., pseudocode or simple Python)'], target_words=500, tags=['mechanics', 'requires_code'], requires_research=False, requires_citations=False, requires_code=True), Task(id=3, title='Implementing Self-Attention Efficiently', goal='Guide readers on optimized strategies for implementing self-attention in practice.', bullets=['Discuss computational complexity of naive self-attention and its quadratic nature with input length', 'Explain techniques like batching, matrix multiplication optimizations, and use of GPU/TPU acceleration', 'Introduce memory-efficient implementations for long sequences (e.g., chunking or sparse attention variants)', 'Highlight libraries and frameworks that support efficient self-attention (e.g., PyTorch, TensorFlow)', 'Provide debugging tips for common performance bottlenecks and numerical stability issues'], target_words=400, tags=['implementation', 'performance', 'debugging'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Handling Edge Cases and Limitations of Self-Attention', goal='Identify common pitfalls and limitations when using self-attention models.', bullets=['Discuss challenges with very long sequences due to memory and computation costs', 'Address issues like lack of explicit positional information and how positional encodings help', 'Explain potential overfitting risks and ways to mitigate them (dropout, regularization)', 'Highlight failure modes such as attention collapse or uniform attention distributions', 'Suggest validation strategies to detect and diagnose such edge cases'], target_words=300, tags=['limitations', 'edge_cases'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Applications and Impact of Self-Attention', goal='Describe how self-attention is used in modern architectures and its practical implications.', bullets=['Illustrate the use of self-attention in Transformer architecture and its role in models like BERT, GPT', 'Explain why self-attention is preferred over RNNs and CNNs for certain sequence modeling tasks', 'Touch on applications beyond NLP, like computer vision (e.g. Vision Transformers) and reinforcement learning', 'Discuss how self-attention enables transfer learning and few-shot adaptation', 'Consider future directions and evolv ...
#  'as_of': '2026-07-06',
#  'recency_days': 3650,
#  'sections': [(1,
#    '## Introduction to Self-Attention\n\nSelf-attention is a mechanism within neural networks that allows each element of an input sequence to dynamically weigh and aggregate information from all other elements in the same sequence. Unlike traditional attention mechanisms, which typically relate a separate query to a different set of keys and values (such as between encoder and decoder in sequence-to-sequence models), self-attention operates entirely within a single input. This makes it particularly powerful for understanding relationships inside the data itself.\n\nHistorically, self-attention emerged from the need to overcome limitations of earlier architectures like recurrent neural networks (RNNs) and convolutional neural networks (CNNs). RNNs process inputs sequentially, which can lead to difficulties in capturing long-range dependencies due to vanishing gradients and high computational cost. CNNs, on the other hand, rely on fixed-size windows that struggle to model global context without stacking many layers. Self-attention was introduced to address these challenges by enabling direct access to all positions in the input simultaneously, fostering richer and more flexible representations.\n\nThe key difference is in how information flows: self-attention computes pairwise interactions between all input elements in parallel, while convolutions focus on local neighborhoods, and RNNs maintain a hidden state that updates step-by-step. This global receptive field allows self-attention to capture complex dependencies regardless of distance within the sequence.\n\nIntuitively, self-attention can be seen as letting each part of the input "look around" and decide which other parts are most relevant for understanding its own meaning. For example, in a sentence, a word can attend to other words to resolve ambiguity or gain additional context.\n\nSelf-attention has become foundational in domains like natural language processing (NLP) and computer vision. In NLP, it powers transformer architectures that excel at tasks such as machine translation, sentiment analysis, and question answering. In computer vision, self-attention helps capture relationships between distant pixels or regions, improving object recognition and scene understanding.\n\nBy enabling efficient, context-aware representations across diverse inputs, self-attention continues to drive advances across modern deep learning applications.'),
#   (2,
#    '## Core Mechanics of Self-Attention\n\nSelf-attention is a powerful mechanism that allows a model to weigh the importance of different parts of an input sequence when producing representations. At its core, the process revolves around three key components: queries, keys, and values.\n\n- **Queries, Keys, and Values**:  \n  Imagine each element in your input sequence is transformed into three vectors—query (Q), key (K), and value (V). Queries and keys are used to calculate attention scores, which represent how much focus the model should place on other parts of the sequence relative to each query. Values are the vectors that actually carry the information to be aggregated based on these scores.\n  \n- **Calculating Attention Scores with Dot Product**:  \n  To find how much a particular query attends to each key, we compute the dot product of the query vector with every key vector. Since the dimensionality of these vectors affects the magnitude of the dot products, we scale the result by dividing by the square root of the key dimension \\(d_k\\). This scaling prevents scores from growing too large, which could make the subsequent softmax step less stable.\n  \n  Mathematically:\n  \\[\n  \\text{attention\\_score}(Q_i, K_j) = \\frac{Q_i \\cdot K_j}{\\sqrt{d_k}}\n  \\]\n\n- **Softmax Normalization of Attention Scores**:  \n  The raw attention scores are unbounded and not normalized. Applying the softmax function converts them into a probability distribution across the input sequence, ensuring the weights sum to 1. This normalization makes it easy to interpret these values as relative importance.\n\n  \\[\n  \\alpha_{ij} = \\text{softmax}\\left(\\frac{Q_i \\cdot K_j}{\\sqrt{d_k}}\\right)\n  \\]\n\n- **Applying Attention Weights to Values**:  \n  Once the normalized attention weights \\(\\alpha\\) are obtained, they are used to compute a weighted sum of the value vectors. This weighted combination produces the attended output representation for each element of the sequence.\n\n  \\[\n  \\text{output}_i = \\sum_j \\alpha_{ij} V_j\n  \\]\n\n- **Multi-Head Attention for Richer Representations**:  \n  Instead of performing a single attention computation, multi-head attention splits queries, keys, and values into multiple subspaces (heads). Each head learns to capture different aspects of the input relationships independently. Their outputs are then concatenated and linearly transformed to produce the final result. This allows the model to attend to information from various representation subspaces simultaneously.\n\nHere\'s a minimal Python sketch demonstrating the core self-attention calculations for a single head:\n\n```python\nimport numpy as np\n\ndef self_attention(Q, K, V):\n    """\n    Compute self-attention for queries Q, keys K, and values V.\n\n    Args:\n        Q: (seq_len, d_k) - query matrix\n        K: (seq_len, d_k) - key matrix\n        V: (seq_len, d_v) - value matrix\n\n    Returns:\n        output: (seq_len, d_v) - attended output\n        attention_weights: (seq_len, seq_len) - softmax-normalized scores\n    """\n    d_k = Q.shape[1]\n    # Step 1: Dot product between queries and keys (transpose keys)\n    scores = np.dot(Q, K.T) / np.sqrt(d_k)\n\n    # Step 2: Softmax normalization\n    exp_scores = np.exp(scores - np.max(scores, axis=1, keepdims=True))\n    attention_weights = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)\n\n    # Step 3: Weighted sum of values\n    output = np.dot(attention_weights, V)\n    return output, attention_weights\n\n# Example usage with random vectors\nseq_len, d_k, d_v = 4, 64, 64\nQ = np.random.rand(seq_len, d_k)\nK = np.random.rand(seq_len, d_k)\nV = np.random.rand(seq_len, d_v)\n\noutput, attn = self_attention(Q, K, V)\nprint("Attended output shape:", output.shape)\n```\n\nThis code encapsulates the essential computations: dot-product scoring, scaling, softmax normalization, and weighted aggregation. Extending this to multi-head attention involves splitting Q, K, V int ...
#   (3,
#    '## Implementing Self-Attention Efficiently\n\nWhen implementing self-attention, one of the main challenges is its computational complexity. Naively computing self-attention requires calculating interactions between every pair of tokens in the input sequence, resulting in a complexity of O(n²), where n is the sequence length. This quadratic scaling becomes a major performance bottleneck, especially for long sequences, making straightforward implementations impractical for many real-world applications.\n\nTo address these challenges, several optimization strategies are commonly employed:\n\n- **Batching and Matrix Multiplication Optimizations**: Leveraging batch processing lets you compute self-attention efficiently across multiple samples simultaneously. Modern deep learning libraries optimize large matrix multiplications, so structuring your data into batches and using efficient linear algebra primitives can greatly speed up computation. Avoid explicit for-loops over tokens and instead use batched matrix operations whenever possible.\n\n- **Hardware Acceleration (GPU/TPU)**: The highly parallel structure of self-attention aligns well with GPU and TPU architectures. Utilizing these accelerators can massively reduce training and inference times. Make sure to take advantage of device-specific libraries and kernels optimized for matrix operations and parallel computations.\n\n- **Memory-Efficient Long Sequence Approaches**: For very long sequences, the quadratic memory and compute costs can exceed hardware limits. Techniques such as chunking the input into smaller parts or employing sparse attention mechanisms limit the number of token interactions computed. For example, sparse attention restricts attention to a local window or selected tokens only, effectively reducing complexity while maintaining performance.\n\nSeveral popular deep learning frameworks facilitate efficient self-attention implementation:\n\n- **PyTorch** provides native support for batch matrix operations and GPU acceleration, with an active ecosystem of optimized transformer libraries.\n- **TensorFlow** offers similar benefits, with XLA compilation and TPU support for faster attention computations.\n- Libraries like **Hugging Face Transformers** abstract many efficiency optimizations and include implementations of sparse and memory-friendly attention variants.\n\nDebugging performance issues often starts with identifying bottlenecks such as inefficient data loading, unnecessary data copies between CPU and GPU, or poor memory utilization. Monitoring GPU utilization, profiling matrix operations, and checking for excessive synchronization points can reveal slowdowns. Numerical stability is another common concern, especially with large exponentials in the attention softmax—using techniques like scaled dot-product attention with scaling factors and ensuring proper data types (e.g., float32 or mixed precision) helps maintain stable gradients.\n\nFocusing on these practical strategies lets developers implement self-attention that scales well and runs efficiently in both research and production environments.'),
#   (4,
#    '## Handling Edge Cases and Limitations of Self-Attention\n\nWhile self-attention has revolutionized many tasks, it comes with challenges developers need to be aware of to build robust models.\n\nOne major limitation is the high memory and computational cost when processing very long sequences. Self-attention computes pairwise interactions between all tokens, so the cost scales quadratically with sequence length. This can make training and inference prohibitively expensive or slow, especially on limited hardware.\n\nAnother challenge is that self-attention does not inherently encode positional information about tokens. Without this, the model treats input elements as a "bag of tokens" with no order awareness. Positional encodings, either fixed or learned, must be added to embed sequential context and allow the model to distinguish token positions, which is crucial for tasks like language understanding.\n\nSelf-attention models are also prone to overfitting, especially with limited data or large model sizes. Applying techniques like dropout on attention weights or outputs, weight regularization, and data augmentation can help combat overfitting and improve generalization.\n\nFailure modes specific to self-attention include phenomena like attention collapse, where attention distributions become overly concentrated or uniform. This can hinder learning by limiting the model’s ability to focus on informative parts of the input. Monitoring the attention weight distributions during training can provide insights into such issues.\n\nTo detect and diagnose these edge cases, it’s important to validate models thoroughly. Use diverse validation sets and visualize attention maps to ensure meaningful focus patterns. Tracking metrics related to convergence and overfitting can alert you to problems early, allowing timely adjustments in architecture or training procedures.\n\nBeing mindful of these limitations and strategies will enable you to use self-attention more effectively in production systems.'),
#   (5,
#    '## Applications and Impact of Self-Attention\n\nSelf-attention is at the core of modern deep learning architectures, revolutionizing how models process sequential and structured data. The Transformer architecture, introduced in 2017, relies heavily on self-attention mechanisms to weigh the importance of different words within a sentence. This approach underpins powerful models like BERT and GPT, enabling them to capture complex contextual relationships efficiently.\n\nUnlike traditional Recurrent Neural Networks (RNNs) and Convolutional Neural Networks (CNNs), self-attention processes all tokens in a sequence simultaneously rather than step-by-step or through fixed-window filters. This parallelism not only speeds up training but also better handles long-range dependencies, as every element can attend to every other element directly. This makes self-attention especially suitable for tasks like language modeling, where understanding context over long text spans is crucial.\n\nBeyond natural language processing (NLP), self-attention has expanded into other domains. In computer vision, Vision Transformers (ViTs) have demonstrated competitive results by applying self-attention to image patches instead of pixels, learning spatial relationships without convolution. In reinforcement learning, self-attention helps agents interpret complex, multi-step interactions by focusing dynamically on different parts of their observation or memory, improving decision-making.\n\nOne of the most practical advantages of self-attention is its facilitation of transfer learning and few-shot adaptation. Models like GPT can be fine-tuned on new tasks with minimal additional data, thanks to their flexible, context-aware attention mechanisms. This adaptability reduces resource demands and accelerates the deployment of AI solutions across diverse applications.\n\nLooking ahead, research continues to refine self-attention to address challenges such as quadratic complexity with sequence length. Variants like sparse attention or linearized attention aim to retain expressive power while improving efficiency. As these innovations mature, self-attention will likely become even more ubiquitous, powering smarter and faster models across fields.'),
#   (6,
#    '## Summary and Next Steps for Learning Self-Attention\n\nSelf-attention is a powerful mechanism that allows models to weigh the importance of different parts of input data dynamically. By computing relationships within the input sequence, it captures context efficiently, enabling more nuanced understanding than traditional approaches. This makes it fundamental to many state-of-the-art models in NLP and beyond.\n\nTo deepen your grasp, start by implementing simple self-attention modules in your projects or following hands-on tutorials. Experimenting with code helps solidify concepts and reveals practical considerations like computational cost and input representation.\n\nFor further study, explore foundational research papers such as “Attention Is All You Need,” deep-dive tutorials available on popular ML platforms, and libraries like PyTorch or TensorFlow that provide attention modules. Additionally, consider extending your learning by integrating self-attention with convolutional or recurrent networks, or investigating variants like multi-head or sparse attention to address scalability and performance challenges. These efforts will broaden your skill set and open doors to advanced applications.')],
#  'final': '# Understanding Self-Attention: Foundations and Applications\n\n## Introduction to Self-Attention\n\nSelf-attention is a mechanism within neural networks that allows each element of an input sequence to dynamically weigh and aggregate information from all other elements in the same sequence. Unlike traditional attention mechanisms, which typically relate a separate query to a different set of keys and values (such as between encoder and decoder in sequence-to-sequence models), self-attention operates entirely within a single input. This makes it particularly powerful for understanding relationships inside the data itself.\n\nHistorically, self-attention emerged from the need to overcome limitations of earlier architectures like recurrent neural networks (RNNs) and convolutional neural networks (CNNs). RNNs process inputs sequentially, which can lead to difficulties in capturing long-range dependencies due to vanishing gradients and high computational cost. CNNs, on the other hand, rely on fixed-size windows that struggle to model global context without stacking many layers. Self-attention was introduced to address these challenges by enabling direct access to all positions in the input simultaneously, fostering richer and more flexible representations.\n\nThe key difference is in how information flows: self-attention computes pairwise interactions between all input elements in parallel, while convolutions focus on local neighborhoods, and RNNs maintain a hidden state that updates step-by-step. This global receptive field allows self-attention to capture complex dependencies regardless of distance within the sequence.\n\nIntuitively, self-attention can be seen as letting each part of the input "look around" and decide which other parts are most relevant for understanding its own meaning. For example, in a sentence, a word can attend to other words to resolve ambiguity or gain additional context.\n\nSelf-attention has become foundational in domains like natural language processing (NLP) and computer vision. In NLP, it powers transformer architectures that excel at tasks such as machine translation, sentiment analysis, and question answering. In computer vision, self-attention helps capture relationships between distant pixels or regions, improving object recognition and scene understanding.\n\nBy enabling efficient, context-aware representations across diverse inputs, self-attention continues to drive advances across modern deep learning applications.\n\n## Core Mechanics of Self-Attention\n\nSelf-attention is a powerful mechanism that allows a model to weigh the importance of different parts of an input sequence when producing representations. At its core, the process revolves around three key components: queries, keys, and values.\n\n- **Queries, Keys, and Values**:  \n  Imagine each element in your input sequence is transformed into three vectors—query (Q), key (K), and value (V). Queries and keys are used to calculate attention scores, which represent how much focus the model should place on other parts of the sequence relative to each query. Values are the vectors that actually carry the information to be aggregated based on these scores.\n  \n- **Calculating Attention Scores with Dot Product**:  \n  To find how much a particular query attends to each key, we compute the dot product of the query vector with every key vector. Since the dimensionality of these vectors affects the magnitude of the dot products, we scale the result by dividing by the square root of the key dimension \\(d_k\\). This scaling prevents scores from growing too large, which could make the subsequent softmax step less stable.\n  \n  Mathematically:\n  \\[\n  \\text{attention\\_score}(Q_i, K_j) = \\frac{Q_i \\cdot K_j}{\\sqrt{d_k}}\n  \\]\n\n- **Softmax Normalization of Attention Scores**:  \n  The raw attention scores are unbounded and not normalized. Applying the softmax function converts them into a probability distribution across the inp ...
