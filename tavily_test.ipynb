# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_25344\1690773881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_25344\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT - Wikipedia',
#   'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#   'content': 'Generative AI chatbot by OpenAI\n\n| ChatGPT |\n\n| Developer | OpenAI |\n| Release | November 30, 2022 (3 years ago) (2022-11-30) |\n| Stable release | June 18, 2026 (15 days ago) (2026-06-18) |\n|  |\n| Engine | GPT-5.5 |\n| Platform | Cloud computing platforms |\n| Available in | 59 languages |\n| Type |  Chatbot  Large language model  Generative pre-trained transformer |\n| License | Proprietary service |\n| Website | chatgpt.com |\n\n \n\n|  |',
#   'score': 0.9459663},
#  {'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#   'url': 'https://wpexperts.io/blog/chatgpt-version-history',
#   'content': 'Performance Update\n\nDecember 2022\n\nChatGPT launched a massive update that helped user experience, usability, and response time.\n\nChatGPT Launch\n\nNovember 2022\n\nChatGPT started its journey and introduced key advancements in NLP (Natural Language Processing).\n\nThe above ChatGPT version list indicates that previous versions of ChatGPT and ChatGPT’s latest releases are equally important when understanding the effectiveness and contributions of AI to web development, digital marketing, web design, and other domains.\n\n## What’s New in GPT-5.5?\n\nAs you may know, GPT-5.5 was officially launched on April 23, 2026. The latest model introduces major advancements in reasoning, agentic coding, deep research, and autonomous computer use. Here are some of its standout features: [...] ChatGPT Versions\n\nRelease Date\n\nSalient Features\n\nChatGPT 5.6\n\nJune 2026\n\nGPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest).\n\nChatGPT 5.4\n\nMarch 2026\n\nIt focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. \n\nChatGPT 5.3\n\nGPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.\n\nIt improves collaboration and supports full-cycle software development. It offers more accurate answers. \n\nChatGPT 5.2\n\nDecember 2025\n\nGPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. [...] |  |  |  |\n --- \n| ChatGPT Versions | Release Date | Salient Features |\n| ChatGPT 5.6 | June 2026 | GPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest). |\n| ChatGPT 5.4 | March 2026 | It focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. |\n| ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026. | It improves collaboration and supports full-cycle software development. It offers more accurate answers. |',
#   'score': 0.9436445}]

# %%
for r in results:
    print(r['content'])
# Out:
# Generative AI chatbot by OpenAI
#
# | ChatGPT |
#
# | Developer | OpenAI |
# | Release | November 30, 2022 (3 years ago) (2022-11-30) |
# | Stable release | June 18, 2026 (15 days ago) (2026-06-18) |
# |  |
# | Engine | GPT-5.5 |
# | Platform | Cloud computing platforms |
# | Available in | 59 languages |
# | Type |  Chatbot  Large language model  Generative pre-trained transformer |
# | License | Proprietary service |
# | Website | chatgpt.com |
#
#
#
# |  |
# Performance Update
#
# December 2022
#
# ChatGPT launched a massive update that helped user experience, usability, and response time.
#
# ChatGPT Launch
#
# November 2022
#
# ChatGPT started its journey and introduced key advancements in NLP (Natural Language Processing).
#
# The above ChatGPT version list indicates that previous versions of ChatGPT and ChatGPT’s latest releases are equally important when understanding the effectiveness and contributions of AI to web development, digital marketing, web design, and other domains.
#
# ## What’s New in GPT-5.5?
#
# As you may know, GPT-5.5 was officially launched on April 23, 2026. The latest model introduces major advancements in reasoning, agentic coding, deep research, and autonomous computer use. Here are some of its standout features: [...] ChatGPT Versions
#
# Release Date
#
# Salient Features
#
# ChatGPT 5.6
#
# June 2026
#
# GPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest).
#
# ChatGPT 5.4
#
# March 2026
#
# It focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking.
#
# ChatGPT 5.3
#
# GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.
#
# It improves collaboration and supports full-cycle software development. It offers more accurate answers.
#
# ChatGPT 5.2
#
# December 2025
#
# GPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. [...] |  |  |  |
#  ---
# | ChatGPT Versions | Release Date | Salient Features |
# | ChatGPT 5.6 | June 2026 | GPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest). |
# | ChatGPT 5.4 | March 2026 | It focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. |
# | ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026. | It improves collaboration and supports full-cycle software development. It offers more accurate answers. |
